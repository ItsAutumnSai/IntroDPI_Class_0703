# %%
for i in range(5, 9):
    print(i)
# Out:
# 5
# 6
# 7
# 8

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
img = cv2.imread('./ImageingProcessing/image1.jpg')
if img is None:
    print("no image loaded...")

# %%
img = cv2.resize(img, (250, 250))
print("Data type: ", type(img))
print("Shape: ", img.shape)
print("Dtype: ", img.dtype)
print(f"Height = {img.shape[0]} pixel")
print(f"Width = {img.shape[1]} pixel")
print(f"Channel = {img.shape[2]} (BGR)")

img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# Out:
# Data type:  <class 'numpy.ndarray'>
# Shape:  (250, 250, 3)
# Dtype:  uint8
# Height = 250 pixel
# Width = 250 pixel
# Channel = 3 (BGR)

# %%
plt.figure(figsize=(4, 6))
plt.imshow(img_RGB)
plt.title('resized & conversioned BGR to RGB image')
plt.axis('off')
plt.show()

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_crop = img_gray[60:90, 100:130]

print(img_crop)
# Out:
# [[ 47  73  56  67  52  65  85  66  65  49  58  56  63  48  72  60  62  49
#    59  59  77  65  74  57  69  62  57  61  61  64]
#  [ 72  69  48  41  63  55  63 103  66  65  79 102  96  54  73  60  51  72
#    58  70  68  58  60  59  61  60  57  70  66  71]
#  [ 57  59  54  64  65  62  67  88  67  73  55  68 110  92  63  53  56  56
#    55  56  67  64  48  57  59  70  67  64  68  69]
#  [ 56  52  57  68  60  47  63  48  73  54  56  78  60  56  59  58  68  70
#    63  68  69  60  51  58  64  53  68  71  64  48]
#  [ 59  71  56  62  56  50  52  60  61  61  49  92  77  69  50  61  50  55
#    59  64  53  51  46  43  54  52  67  63  55  68]
#  [ 60  74  58  55  44  59  57  53  75  65  44  83 109  91  87  58  55  68
#    46  61  63  69  98  42  44  44  55  58  49  68]
#  [ 52  66  70  44  51  56  62  72  63  61  43  70  66  98  79  55  69  67
#    61  72  51  56  63  93  53  53  69  47  70  61]
#  [ 64  58  58  48  77  50  55  49  52  47  85  61  94  76  94  55  51  53
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].imshow(img_gray, cmap='gray', vmin=0, vmax=255)
axes[0].set_title('grayscale')
axes[0].axis('off')
rect = patches.Rectangle((60, 130), 8, 8, linewidth=2, edgecolor='red', facecolor='none')
axes[0].add_patch(rect)
axes[0].text(110, 145, 'area crop', color='red', fontsize=12)

axes[1].imshow(img_crop, cmap='gray', vmin=0, vmax=255)
for i in range(30):
    for j in range(30):
        nilai = img_crop[i, j]
        text_color = 'white' if nilai < 70 else 'black'
        axes[1].text(j, i, str(nilai), ha='center', va='center',
                     fontsize=5, color=text_color, fontweight='bold')
axes[1].set_title('30x30 pixel\nNumber = f(x,y)')
axes[1].axis('off')
plt.tight_layout()
plt.show()
